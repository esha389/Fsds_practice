# %% [markdown]
# - if
# - else
# - nested if
# - if elif else

# %%
if True:
    print('data science')
# Out:
# data science

# %%
if False:
    print('data science')
print('goodbye')
# Out:
# goodbye

# %%
if True:
    print('data science')
else:
    print ('bye')
# Out:
# data science

# %%
x = 4
r = x % 2
if r == 0:
    print('even number')
else:
    print('odd number')
# Out:
# even number

# %%
x = 5
r = x % 2

if r != 0:
    print('odd number')
# Out:
# odd number

# %%
x = 7
r = x % 2
if r == 1:
    print('even number')
# Out:
# even number

# %%
x = 4
r = x % 2
if r == 0:
    print('even number')
    if x > 5:
        print('greater number')
    else:
        print('lesser number')
else:
    print('odd number')
# Out:
# even number
# lesser number

# %%
x = int(input('enter number:'))

if x == 2:
    print('two')
if x == 10:
    print('ten')
else:
    print('non zero ')
# Out:
# enter number: 2
# two
# non zero

# %%
x = 5

if x == 1:
    print('one')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('four')

else:
    print('number not found')
# Out:
# number not found

# %% [markdown]
# LOOPS

# %%
x = 28 #initializing
while x<=30: #condition
    print('loading')
    x = x + 1
# Out:
# loading
# loading
# loading

# %%
x = 5
while x >= 1:
    print('not found', x)
    x = x - 1
# Out:
# not found 5
# not found 4
# not found 3
# not found 2
# not found 1

# %%
i = 2
while i <= 5:
    print('Hi esha', end = ' - ')

    j = 1
    while j <=3:
        print('welcome', end = ' - ')
        j = j + 1
        
    i = i + 1
    print()
# Out:
# Hi esha - welcome - welcome - welcome -
# Hi esha - welcome - welcome - welcome -
# Hi esha - welcome - welcome - welcome -
# Hi esha - welcome - welcome - welcome -
