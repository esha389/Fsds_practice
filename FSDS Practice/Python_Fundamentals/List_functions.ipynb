# %%
list1 = []
print(type(list1))
# Out:
# <class 'list'>

# %%
list1 = [12,3000,'amount']

# %%
list5 = ['xperson', 25 , 80000, 7]
list5
# Out:
# ['xperson', 25, [80000, 7]]

# %%
list7 = ['Asif', 25 ,[50, 100],[150, 90] , {'John' , 'David'}]

# %%
list7
# Out:
# ['Asif', 25, [50, 100], [150, 90], {'David', 'John'}]

# %%
len(list7)
# Out:
# 5

# %%
len(list5)
# Out:
# 3

# %%
list_guest = ['esha', 'megha', 'javed', 'anu', 'andy','rupa']
list_guest[:0]
# Out:
# []

# %%
list_guest[0:]
# Out:
# ['esha', 'megha', 'javed', 'anu', 'andy', 'rupa']

# %%
list_guest[1:0]
# Out:
# []

# %%
list_guest[0:1]
# Out:
# ['esha']

# %%
list_ph = [ 8,0,1,9,8,1,3,0,8,9]

# %%
list_ph[0:10]
# Out:
# [8, 0, 1, 9, 8, 1, 3, 0, 8, 9]

# %%
list_ph[:2]
# Out:
# [8, 0]

# %%
list_ph[:-1]
# Out:
# [8, 0, 1, 9, 8, 1, 3, 0, 8]

# %%
list_ph[-1:]
# Out:
# [9]

# %%
list_ph[:-6]
# Out:
# [8, 0, 1, 9]

# %%
list_ph[-6:]
# Out:
# [8, 1, 3, 0, 8, 9]

# %%
list_ph
# Out:
# [8, 0, 1, 9, 8, 1, 3, 0, 8, 9]

# %%
list_ph.append(9)

# %%
list_ph
# Out:
# [8, 0, 1, 9, 8, 1, 3, 0, 8, 9, 9]

# %%
listN = ['one', 'two', 'three','four','five','six','seven','eight']

# %%
listN
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
listN.insert(8,'nine')

# %%
listN
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
listN.insert(9, 'ten')

# %%
listN
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
listN.insert(2, 'TWO')

# %%
listN
# Out:
# ['one',
#  'two',
#  'TWO',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten']

# %%
listN.remove('TWO')

# %%
listN
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
listN.pop()
# Out:
# 'ten'

# %%
listN.pop(2)
# Out:
# 'three'

# %%
listN.insert(5,'ERROR')

# %%
listN
# Out:
# ['one',
#  'two',
#  'four',
#  'five',
#  'six',
#  'ERROR',
#  'ERROR',
#  'seven',
#  'eight',
#  'nine']

# %%
del listN[5]

# %%
listN
# Out:
# ['one', 'two', 'four', 'five', 'six', 'ERROR', 'seven', 'eight', 'nine']

# %%
listN.remove('ERROR')

# %%
listN
# Out:
# ['one', 'two', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
listN.clear()

# %%
listN
# Out:
# []

# %%
del listN

# %%
listN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 listN
#
# NameError: name 'listN' is not defined

# %% [markdown]
# COPY LIST

# %%
home_number = [9,8,9,8,9,8,4,5,6,7]

# %%
len(home_Number)
# Out:
# 10

# %%
mobile_number = home_number

# %%
home_number
# Out:
# [9, 8, 9, 8, 9, 8, 4, 5, 6, 7]

# %%
id(mobile_number)
# Out:
# 2243477814784

# %%
id(home_number)
# Out:
# 2243477814784

# %%
office_number = mobile_number.copy()

# %%
office_number
# Out:
# [9, 8, 9, 8, 9, 8, 4, 5, 6, 7]

# %%
office_number[0] = 0

# %%
office_number
# Out:
# [0, 8, 9, 8, 9, 8, 4, 5, 6, 7]

# %%
office_number.insert(1, 4)

# %%
office_number
# Out:
# [0, 4, 8, 9, 8, 9, 8, 4, 5, 6, 7]

# %%
office_number[2] = 0

# %%
office_number
# Out:
# [0, 4, 0, 9, 8, 9, 8, 4, 5, 6, 7]

# %%
mobile_number
# Out:
# [9, 8, 9, 8, 9, 8, 4, 5, 6, 7]

# %%
id(office_number)
# Out:
# 2243477928064

# %%
id(mobile_number)
# Out:
# 2243477814784

# %% [markdown]
# JOIN LIST

# %%
name = ['john doe']
phone = [98989989899]
mobile = [9,9,8,9,9,0,9,0,9,1]

# %%
len(mobile)
# Out:
# 10

# %%
customer_details = name + mobile

# %%
customer_details
# Out:
# ['john doe', 9, 9, 8, 9, 9, 0, 9, 0, 9, 1]

# %%
name.extend(mobile)

# %%
name
# Out:
# ['john doe', 9, 9, 8, 9, 9, 0, 9, 0, 9, 1]

# %% [markdown]
# LIST Membership

# %%
newhire = ['esha','noor','garvita','sashi','koyal','rebacca','soumya']

# %%
len(newhire)
# Out:
# 7

# %%
'sashi' in newhire
# Out:
# True

# %%
'ayesha' in newhire
# Out:
# False

# %%
if 'sashi' in newhire:
    print('new hire added')
else:
    print('not added')

# %%
if 'ayesha' in newhire:
        print('new hire added')
else:
    print('not added')
# Out:
# not added

# %% [markdown]
# REVERSE & SORT

# %%
newhire
# Out:
# ['esha', 'noor', 'garvita', 'sashi', 'koyal', 'rebacca', 'soumya']

# %%
mobile_number
# Out:
# [9, 8, 9, 8, 9, 8, 4, 5, 6, 7]

# %%
mobile_number.reverse()

# %%
mobile_number
# Out:
# [7, 6, 5, 4, 8, 9, 8, 9, 8, 9]

# %%
newhire.reverse()

# %%
newhire
# Out:
# ['soumya', 'rebacca', 'koyal', 'sashi', 'garvita', 'noor', 'esha']

# %%
mobile_number = mobile_number[::-1]

# %%
mobile_number
# Out:
# [9, 8, 9, 8, 9, 8, 4, 5, 6, 7]

# %%
newhire = newhire[::-1]

# %%
newhire
# Out:
# ['esha', 'noor', 'garvita', 'sashi', 'koyal', 'rebacca', 'soumya']

# %%
marks = [80,56,78,34,96,22]

# %%
marks.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 marks.sort()
#
# AttributeError: 'NoneType' object has no attribute 'sort'

# %% [markdown]
# LOOP through LIST

# %%
S1_marks = [67,89,45,32,67,99,35,22]
for i in S1_marks:
    print(i)
# Out:
# 67
# 89
# 45
# 32
# 67
# 99
# 35
# 22

# %%
groceries = ['milk','eggs','bread','butter','yogurt','paneer']
for i in enumerate (groceries):
    print(i)
# Out:
# (0, 'milk')
# (1, 'eggs')
# (2, 'bread')
# (3, 'butter')
# (4, 'yogurt')
# (5, 'paneer')

# %%
furniture = ['chair','table','sofa','bed','cot','bed']

# %%
furniture.count('bed')
# Out:
# 2
