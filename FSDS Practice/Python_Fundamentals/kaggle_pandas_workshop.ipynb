# %%
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\Dell\Downloads\archive\movie.csv')

# %%
movies.shape
# Out:
# (27278, 3)

# %%
ratings = pd.read_csv(r'C:\Users\Dell\Downloads\archive\rating.csv')

# %%
tags = pd.read_csv(r'C:\Users\Dell\Downloads\archive\tag.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %% [markdown]
# DATA ANALYSIS

# %%
print(movies.columns)
print(tags.columns)
print(ratings.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='str')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='str')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='str')

# %%
print(movies.columns)
print(tags.columns)
print(ratings.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='str')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='str')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='str')

# %% [markdown]
# DATA STRUCTURES

# %%
row_0 = tags.iloc[1]
(row_0)
# Out:
# userId                        65
# movieId                      208
# tag                    dark hero
# timestamp    2013-05-10 01:41:18
# Name: 1, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='str')

# %%
row_200 = tags.iloc[200]

# %%
row_200
# Out:
# userId                       129
# movieId                    55280
# tag                  dork people
# timestamp    2011-02-05 21:06:06
# Name: 200, dtype: object

# %%
'rating' in row_0
# Out:
# False

# %%
row_0.name
# Out:
# 1

# %%
row_0 = row_0.rename('firstRow')
row_0.name
# Out:
# 'firstRow'

# %% [markdown]
# DATA FRAMES

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='str')

# %%
tags.iloc[[0,11,500]] #acessing rows using index
# Out:
#      userId  movieId                tag            timestamp
# 0        18     4141        Mark Waters  2009-04-24 18:19:40
# 11       65     1783      noir thriller  2013-05-10 01:39:43
# 500     342    55908  entirely dialogue  2012-01-31 18:41:16

# %% [markdown]
# Descriptive Statistics

# %%
rating['rating'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 rating['rating'].describe()
#
# NameError: name 'rating' is not defined

# %%
ratings = pd.read_csv(r'C:\Users\Dell\Downloads\archive\rating.csv')

# %%
ratings['rating'].describe()

# %%
filter1 = ratings['rating'] > 0
filter1.all()

# %% [markdown]
# DATA CLEANING : HANDLING MISSING DATA

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any().any()
# Out:
# np.False_

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
ratings.isnull().any().any()
# Out:
# np.False_

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.isnull().any().any()
# Out:
# np.True_

# %%
tags = tags.dropna()

# %%
tags.isnull().any().any()
# Out:
# np.False_

# %% [markdown]
# DATA VISUALIZATION

# %%
# %matplotlib inline
ratings.hist(column = 'rating', figsize = (10, 6))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
ratings.boxplot(column='rating', figsize=(10,5))
# Out:
# <Axes: >

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: str

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating            timestamp
# 20000253  138493    60816     4.5  2009-12-03 18:32:43
# 20000254  138493    61160     4.0  2009-11-16 16:55:37
# 20000255  138493    65682     4.5  2009-10-17 21:52:53
# 20000256  138493    66762     4.5  2009-10-17 18:50:08
# 20000257  138493    68319     4.5  2009-12-07 18:15:20
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]

tag_counts[:10].plot(kind = 'bar', figsize = (10,5))
# Out:
# <Axes: xlabel='tag'>

# %%
is_highly_rated = ratings['rating'] >= 5.0
ratings[is_highly_rated][30:50]
# Out:
#      userId  movieId  rating            timestamp
# 239       3       50     5.0  1999-12-11 13:13:38
# 242       3      175     5.0  1999-12-11 13:32:13
# 244       3      223     5.0  1999-12-11 13:20:44
# 245       3      260     5.0  1999-12-11 13:09:02
# 246       3      316     5.0  1999-12-14 12:51:10
# 247       3      318     5.0  1999-12-11 13:09:26
# 248       3      329     5.0  1999-12-14 12:53:41
# 252       3      457     5.0  1999-12-11 13:16:55
# 253       3      480     5.0  1999-12-14 12:50:20
# 254       3      490     5.0  1999-12-11 13:30:41
# 256       3      541     5.0  1999-12-11 13:14:07
# 258       3      593     5.0  1999-12-11 13:16:55
# 263       3      858     5.0  1999-12-11 13:01:07
# 264       3      904     5.0  1999-12-11 13:04:10
# 267       3      924     5.0  1999-12-11 13:10:12
# 268       3      953     5.0  1999-12-11 13:11:52
# 271       3     1060     5.0  1999-12-11 13:18:30
# 272       3     1073     5.0  1999-12-11 13:20:44
# ...

# %%
is_action= movies['genres'].str.contains('Action')
movies[is_action][5:15]
# Out:
#     movieId                                      title  \
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                            genres
# 22          Action|Crime|Thriller
# 41             Action|Crime|Drama
# 43       Action|Adventure|Fantasy
# 50          Action|Drama|Thriller
# 65         Action|Sci-Fi|Thriller
# 69  Action|Comedy|Horror|Thriller
# 70                         Action
# 75         Action|Sci-Fi|Thriller
# 77    Action|Crime|Drama|Thriller
# ...

# %%
movies[is_action].head(15)
# Out:
#     movieId                                      title  \
# 5         6                                Heat (1995)
# 8         9                        Sudden Death (1995)
# 9        10                           GoldenEye (1995)
# 14       15                    Cutthroat Island (1995)
# 19       20                         Money Train (1995)
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                                 genres
# 5                Action|Crime|Thriller
# ...

# %%
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      239125
# 1.0      680732
# 1.5      279252
# 2.0     1430997
# 2.5      883398
# 3.0     4291193
# 3.5     2200156
# 4.0     5561926
# 4.5     1534824
# 5.0     2898660

# %%
average_rating = ratings[['movieId','rating']].groupby('movieId').mean()
average_rating.tail()
# Out:
#          rating
# movieId
# 131254      4.0
# 131256      4.0
# 131258      2.5
# 131260      3.0
# 131262      4.0

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags, on='movieId', how='inner')
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag            timestamp
# 0    1644                                 Watched  2014-12-04 23:44:40
# 1    1741                      computer animation  2007-07-08 13:59:15
# 2    1741                 Disney animated feature  2007-07-08 22:21:47
# 3    1741                         Pixar animation  2007-07-08 22:46:10
# 4    1741  T̩a Leoni does not star in this movie  2009-06-15 19:19:33

# %%
ratings.shape

avg_ratings = ratings.groupby("movieId")
avg_ratings.head()
avg_ratings.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 5
#       1 ratings.shape
#       2
#       3 avg_ratings = ratings.groupby("movieId")
#       4 avg_ratings.head()
# ----> 5 avg_ratings.mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
# ...

# %%
is_highly_rated = box_office['rating'] >= 4.0
box_office[is_highly_rated][-5:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 is_highly_rated = box_office['rating'] >= 4.0
#       2 box_office[is_highly_rated][-5:]
#
# NameError: name 'box_office' is not defined

# %%
movie_genres = movies['genres'].str.split('|', expand=True)

# %%
movies['year'] = movies['title'].str.extract('.*\((.*)\).*', expand=True)
