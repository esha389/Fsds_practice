# %% [markdown]
# Data Types

# %%
value1 = 20 
print(value1)
# Out:
# 20

# %%
print(type(value1))
# Out:
# <class 'int'>

# %%
import sys
value2 = 99.99
print(sys.getsizeof(value2)) # size in  byte
# Out:
# 24

# %%
value3 = 25 + 10j
print(value3)
print(sys.getsizeof(value3))
# Out:
# (25+10j)
# 32

# %%
bool1 = True

# %%
bool2 = False

# %%
print(type(bool1))
# Out:
# <class 'bool'>

# %%
print(type(bool2))
# Out:
# <class 'bool'>

# %%
isinstance(bool1, bool)
# Out:
# True

# %%
isinstance(bool2, bool)
# Out:
# True

# %% [markdown]
# String

# %%
str = "hello world"
print(str)
str1 = 'hello world'
print(str1)
# Out:
# hello world
# hello world

# %%
load = 'loading...'
loaded = load*5
print(loaded)
# Out:
# loading...loading...loading...loading...loading...

# %%
len(load)
# Out:
# 10

# %%
len(loaded)
# Out:
# 50

# %% [markdown]
# String Indexing

# %%
name = 'Esha Nissie'
name
# Out:
# 'Esha Nissie'

# %%
name[0]
# Out:
# 'E'

# %%
name[-1]
# Out:
# 'e'

# %%
name[4]
# Out:
# ' '

# %% [markdown]
# String slicing

# %%
name[0:5]
# Out:
# 'Esha '

# %%
name[:]
# Out:
# 'Esha Nissie'

# %% [markdown]
# String concatenation

# %%
first_name = 'esh'
last_name = 'aaa'
full_name = first_name + last_name
print(full_name)
# Out:
# eshaaa

# %% [markdown]
# print() with format method

# %%
customer_name = 'Airah'
credit_score = 780
Loan_status = 'approved'

print('The cardholder {} has credit score of {} and loan is {}'.format(customer_name,credit_score,Loan_status))
# Out:
# The cardholder Airah has credit score of 780 and loan is approved

# %%
Current_balance = 90000
Emi = 7000
Balance_after_emi = Current_balance - Emi
print(f'Cardholder had  {Current_balance}  and monthly emi of  {Emi}  deducted now current balance is  {Balance_after_emi} ')
# Out:
# Cardholder had  90000  and monthly emi of  7000  deducted now current balance is  83000

# %%
print('hello','world',sep = '  ')
# Out:
# hello  world

# %% [markdown]
# Operators

# %%
x = 2

# %%
x -= 2

# %%
x
# Out:
# 6

# %%
x *= 2

# %%
x
# Out:
# 12

# %%
x //= 2
x
# Out:
# 6

# %%
x %= 2

# %%
x
# Out:
# 0

# %%
x = 9
y = 8

x < y
# Out:
# False

# %%
x > y
# Out:
# True

# %%
y < x
# Out:
# True

# %%
y > x
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
x < 2 and y > 2
# Out:
# False

# %%
x < 2 or y > 2
# Out:
# True

# %%
x = False
not x
# Out:
# True
