# %%
d = {1:'one', 2:'two'}

# %%
d
# Out:
# {1: 'one', 2: 'two'}

# %%
d.keys()
# Out:
# dict_keys([1, 2])

# %%
d.values()
# Out:
# dict_values(['one', 'two'])

# %%
d[3] = 'three'
d
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d['four'] = 4
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 'four': 4}

# %%
d.pop('four')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 d.pop('four')
#
# KeyError: 'four'

# %%
d
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
1 in d
# Out:
# True

# %%
3 in d
# Out:
# True

# %%
200 in d
# Out:
# False

# %% [markdown]
# RANGE

# %%
range (0,5)
# Out:
# range(0, 5)

# %%
list(range(0,5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(10,50,5))
# Out:
# [10, 15, 20, 25, 30, 35, 40, 45]

# %% [markdown]
# DICTIONARY

# %%
SSO = {2900:'esha', 2901:'haley',2981:'alex',2903:'clarie',2500:'jay'}

# %%
type(SSO)
# Out:
# dict

# %%
SSO
# Out:
# {2900: 'esha', 2901: 'haley', 2981: 'alex', 2903: 'clarie', 2500: 'jay'}

# %%
new_hire = {29,2,3,5,20,12}
value = 'allowed'

# %%
new_hire
# Out:
# {2, 3, 5, 12, 20, 29}

# %%
approved_newhire = dict.fromkeys(new_hire,value)

# %%
approved_newhire
# Out:
# {2: 'allowed',
#  3: 'allowed',
#  20: 'allowed',
#  5: 'allowed',
#  12: 'allowed',
#  29: 'allowed'}

# %%
d = dict.fromkeys(new_hire)
d
# Out:
# {2: None, 3: None, 20: None, 5: None, 12: None, 29: None}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = [10,20,30] 
mydict3 = dict.fromkeys(keys , value)

# %%
mydict3
# Out:
# {'a': [10, 20, 30], 'b': [10, 20, 30], 'd': [10, 20, 30], 'c': [10, 20, 30]}

# %%
mydict3.keys()
# Out:
# dict_keys(['a', 'b', 'd', 'c'])

# %%
value.append(40)

# %%
mydict3
# Out:
# {'a': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40],
#  'd': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40]}

# %% [markdown]
# ACCESSING

# %%
new_hire[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 new_hire[2]
#
# TypeError: 'set' object is not subscriptable

# %%
id(new_hire)
# Out:
# 1536488258720

# %%
id(approved_newhire)
# Out:
# 1536488080256

# %%
new_hire
# Out:
# {2, 3, 5, 12, 20, 29}

# %%
new_hire.add(9)

# %%
new_hire
# Out:
# {2, 3, 5, 9, 12, 20, 29}

# %%
approved_newhire
# Out:
# {2: 'allowed',
#  3: 'allowed',
#  20: 'allowed',
#  5: 'allowed',
#  12: 'allowed',
#  29: 'allowed'}

# %%
SSO
# Out:
# {2900: 'esha', 2901: 'haley', 2981: 'alex', 2903: 'clarie', 2500: 'jay'}

# %%
SSO[2900]
# Out:
# 'esha'

# %%
SSO.get(2901)
# Out:
# 'haley'

# %%
SSO
# Out:
# {2900: 'esha', 2901: 'haley', 2981: 'alex', 2903: 'clarie', 2500: 'jay'}

# %%
newID = {3900:'luke'}

# %%
SSO.update(newID)

# %%
SSO
# Out:
# {2900: 'esha',
#  2901: 'haley',
#  2981: 'alex',
#  2903: 'clarie',
#  2500: 'jay',
#  3900: 'luke'}

# %%
SSO.pop(2900)
# Out:
# 'esha'

# %%
SSO.popitem()
# Out:
# (3900, 'luke')

# %%
SSO.clear()

# %%
SSO
# Out:
# {}

# %%
del SSO

# %%
SSO
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 SSO
#
# NameError: name 'SSO' is not defined

# %%
mydict = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'} 
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
new = mydict

# %%
new
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
id(new)
# Out:
# 1536491997056

# %%
id(mydict)
# Out:
# 1536491997056

# %%
new = mydict.copy()

# %%
new
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
id(new)
# Out:
# 1536501044352

# %%
new['Name'] = 'alex'

# %%
new
# Out:
# {'Name': 'alex', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %% [markdown]
# LOOP through DICTIONARY

# %%
for i in mydict:
    print(i)
# Out:
# Name
# ID
# DOB
# Address

# %%
for i in new:
    print(i, ':', new[i])
# Out:
# Name : alex
# ID : 12345
# DOB : 1991
# Address : Hilsinki

# %%
for i in new:
    print(new[i])
# Out:
# alex
# 12345
# 1991
# Hilsinki

# %%
'Address' in mydict
# Out:
# True

# %%
all(mydict) # Will Return false as one value is false (Value 0)
# Out:
# True
