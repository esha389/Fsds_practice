# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(2)
# Out:
# '0x2'

# %%
int(0x19)
# Out:
# 25

# %%
12 | 13
# Out:
# 13

# %%
12 & 13
# Out:
# 12

# %%
12 ^ 13
# Out:
# 1

# %%
~13
# Out:
# -14

# %%
12 << 2
# Out:
# 48

# %%
12 << 1
# Out:
# 24

# %%
12 >> 2
# Out:
# 3

# %% [markdown]
# Swap two variable

# %%
a = 7 
b = 9
a = b
b = a
print(a)
print(b)
# Out:
# 9
# 9

# %%
a1 = 9
b1= 8
temp = b1
b1 = a1
a1 = temp
print(a1)
print(b1)
# Out:
# 8
# 9

# %%
a2 = 3
b2 = 2

a2 = b2 + a2
print(a2)
# Out:
# 5

# %%
b2 = a2 - b2
print(b2)
# Out:
# 3

# %%
a2 = a
print(a2)
# Out:
# -5

# %%
a2 = a2 ^ b2
b2 = a2 ^ b2
a2 = a2 ^ b2
print(a2)
print(b2)
# Out:
# 3
# -8

# %% [markdown]
# Complement

# %%
~45
# Out:
# -46

# %%
~90
# Out:
# -91

# %%
35 & 40
# Out:
# 32

# %%
35 | 40
# Out:
# 43
